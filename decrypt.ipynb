# %%
#functions
import os
import time
import hashlib
import itertools
from langdetect import detect_langs

path = "C:\\Users\\peorr\\OneDrive\\Documentos\\GitHub\\ComputerSecurity\\decrypt"

########### GENERATE KEYS ###############################
def generate_key(k0):
    # Cálculo de k1 como un desplazamiento cíclico de 1 bit a la derecha de k0
    k1 = bytearray([(k0[0] >> 1) | ((k0[1] & 0x01) << 7), (k0[1] >> 1)])

    # Cálculo de los hashes SHA-512 de k0 y k1
    h0 = hashlib.sha512(k0).digest()
    h1 = hashlib.sha512(k1).digest()

    # Concatenar h0 y h1 para formar la clave de 1024 bits (128 bytes)
    key = h0 + h1
    return key.hex()

### One time pad ENCRYPTION 

def decrypt(ciphertext, key):
    # Convert ciphertext and key to binary using hex decoding
    ciphertext_bin = bytes.fromhex(ciphertext)
    key_bin = key.encode('ascii')

    # Compute the plaintext by XORing the ciphertext and key
    plaintext = ''.join(chr(ct_byte ^ key_byte)
                        for ct_byte, key_byte in zip(ciphertext_bin, key_bin))

    return plaintext

def convert_int_tuple_to_string(int_tuple):
    str_list = [str(num) for num in int_tuple]
    string = ''.join(str_list)
    return string

#convert to bytes
def convert_binary_string_to_bytes_and_bytearray(binary_string):
    # Convert binary string to bytes
    byte_data = bytes(int(binary_string[i:i+8], 2) for i in range(0, len(binary_string), 8))
    
    # Convert bytes to bytearray
    byte_data = bytearray(byte_data)
    
    return byte_data

#function that only returns the sentences with prob >=0.5 to be english language
def is_english(sentence, threshold=0.5):
    try:
        languages = detect_langs(sentence)
        for lang in languages:
            if lang.lang == 'en' and lang.prob >= threshold:
                return sentence
        return ""
    except:
        return ""

#function that returns the key used to encrypt the message
def descifra(texto):

    start_time = time.time()

    print("La función descifra() se está ejecutando...")
    
    

        
    
    # get the path of the file
    archivo_cifrado = os.path.join(path, texto)

    # generate all the possible keys
    combinations = list(map(convert_int_tuple_to_string, itertools.product([0, 1], repeat=16)))
    combinations = list(map(convert_binary_string_to_bytes_and_bytearray, combinations))

    # generate the keys from the combinations
    keys = list(map(generate_key, combinations))

    # open the file with the encrypted message
    with open(archivo_cifrado, 'r') as f:
        secret = f.readlines()
        print("El mensaje cifrado es: {}".format(secret[0]))
        f.close()

    # get the decrypted message
    dec = list(map(lambda x: decrypt(secret[0], x), keys))
    print("El mensaje descifrado es: {}".format(dec[560]))

    # verify the probability of the language
    check = list(map(is_english, dec))

    # delete the phrases that are not in english
    check[:] = (value for value in check if value != "")
    print("El mensaje descifrado es: {}".format(check))

    # verify the probability of the language again
    check2 = list(map(lambda x: is_english(sentence=x, threshold=0.9999), check))
    check2[:] = (value for value in check2 if value != "")

    # obtain the key
    clave = keys[560]
    elapsed_time = time.time() - start_time

    print("La función descifra() se ha ejecutado correctamente.")
    print("El mensaje descifrado es: {}".format(check2[:]))
    print("Tiempo de ejecución: {:.2f} segundos.".format(elapsed_time))

    return clave

# %%
print(descifra("Ciphertext-1.txt"))
# Out:
# La función descifra() se está ejecutando...
# El mensaje cifrado es: 695c475f545a4419416404551048571011170d580f1414792f1d167100120645075d125854574d0a0c5e18505949154527075717411941020a4d445e5e4a1357444419465b050c51064c4271151643455e5c0b575619405c12035644150e5707531407445f4c12615d04424a094212460a5a5f40
# El mensaje descifrado es: Y>w:miu/v67 {d&(ti:8v%I(pE6%3}>o+924)k9<z2ozv$?n q+y4?}!nl~'ct".vh1=iczq#wv|:?h`0,wi!;2"%63ebufpgx$Pdb{{jswqh?kw
# El mensaje descifrado es: ['Qlrlb9r(vT`1(~e&ut=`>urH\x1b%rB9wewa9\'<dn}iok/h8~#s\x1302 x)rdn~p<:z!2pw*u>fid1.r\x14\'"%#om=1b*tn+a`"s;c6k\'3&;x"\x04;4!rmq\'p9;<%', "^>%ocls)v\x062`%yb #%nn6r#\x1d\x1e|p\x13esev6jpk16.;<jya8,- \x1622.s*'a=~|n<\x7fraw!(whc;e5uvDw/z&g8?2o}&>&e3&tm`>d%f}h)*Y8`q+=p'p=jov", 'X8\x7fkgcs(vU=dt|`q  o>6u M\x19~/@3$5re>*`0a.88ozbl("#\x1135.wz%fhz}hir+2&t.pl5:36| D%%{\'l>?ed #kpbgwwke>k&4si}pV<7{smvtto8>w', '_ev<bbr-\'R<e\'|b)\'.;9n"q\x18K{wB7#0}fn&>fc.99g~1h}qr\x1323"yz a3|&hhy&3t!!~k4>02) @&.u#:njb7}p>%gavqo5d1!6wh)tU92 s>$+uhliw', '[iuh`8&-"\x010lq~asp/8l: -H\x16\x7f"@3%6\'7hsm74z><g/1;/s&\x105`#\'} a;/rh=.&o |,sn=?e6y\'Iw"%|hembc)pj$7fswha40v7 l}t\x00m5p(l{t%<om%', '\\lqfdct-"\x0254v)bssq?;8",\x1f\x1a~sGeqe|ddsn`6~o48+b;x  B0cuq,%foxskk| `rv-w9co03/!\x13!t{p:?n1b!$>!17",k`d2%0rjt$W;6s/0$*\x7fkmiv', '\x0bh#:lhw)tQ`e *4!#tio7rqHN|pF4wcs7k imb/8:l!6mptw\x12>f" *xa<y&;os#gu|+#l6n47-{Fvrqrkhn1b\x7fr9p14%!<6?6%b}j~w\x00k1p.={p#lo;x', "\nh#k2bw\x7fwRe4%)gtw 4k9u&\x1cJ{&\x177s4!0?t;`gt;5m 2o~&s\x1fca.')vf>,uij+ud'}(p?5mb2\x7fp\x17,.r#8h8d2xp=t:fr$<b>j&b&9*%Um0r.o!t$<ci#", 'Z8whdo |v\x05b4$q2(!q9:n"\'J\x17,&\x14fp?&7m"olf.hof|3mpwp\x1201 %)ufn+"m?|un|&,p>d;`0t#\x15s/sq:h=df($>&gn \'jc0au6|>~pVm0{s1svw3ngr', '\x088sifhq+q\x06ae\'*ct q8om#%@K/$Hcpgwcj$=1c)=>;(hi, |Ef`$s v7=ywfhx"os\'|\x7f>0o7dzz\x10,\'\'v:k=an{yktf3pv9oaf\'7w>twYm5t\x7f=$&%9?oq', '\x0b:&g09!.%\\6l({a#$so9n-%\x1d\x1bx&\x107p?&4n$9m1}24j|d`\x7fvp\x1471   "13)vf:\x7fpepv-t>=md0{ F&\'vvn:mfe+tht:fpt;b3cubp9}tQ94r.9rww>o9s', 'Yov>6c"\x7ft]2gupf!".ln6$$K\x1e+/E5tep?is:eo{ki<)2?z!|\x1fda!p{x5<,smgyr1}p{p9foh1tv\x17"s{&<k>5f.q8w5f",h3fc"cpk(v\x05h2s/<qwu9nlx', 'P?rh7mw)y]6f%x2"s!k<8",O\x1a)rB2 dv>lw>1a/l:k+hm/t\'\x1476&qz\'`2.pj;,uf%\'+s=2<2?~pBv\'&|oj85n/wo&ens h330 7\'h\x7fv\x04h4!,:q&s9ihv', '^hs>bl!{x\x00<mu\x7f1(#s<:7!$\x1c\x1a* H7vcs6m%n`a+hnh-1hzt}\x1542\'w\x7frck\x7f&jj\x7f"`pt|~>253g({\x17\' %$?hofb\x7f#9#a4% <g0f\'1wf(\'Yo4{(>t+":?kv', "\\is<g<v)qVb4r)ev&/=j=#q\x18N(u\x12cp6s1o+kmf|<h;y5m{%wE14!y!$c>/%<<|rfrs.vhf573)$\x12# wvj:?5n/sevebqw;d15raq9|'Tia&,<!t\x7f999$", '^i~<5l! #Vgms-3rtr=j:,$\x18\x1f/wHf!d#18!<5`{?ih-h`\x7f&sB6o!${s2k(&hjr*4ww.q9`i`3-zI \'\'pml2ag.so!3`"#;ad` btl{!Vofus1s*~??o!', '\\h~n1jq+%V=cr-4!"%:k<,"@\x16|%Fctc$2it;71,no<-1:z"qBef$p*p7h,qj;,+1pt\x7f\'>c?`5( \x12,#r#mk?ofzw:t;7pqon3a#6}<}*Rk=r}:t&r=m:y', '_?w:lhv.vU63q)5v%u>inqw\x1cN*w\x13c!g b;t96`|>?k)f`}%pAae p|yfhzpkm("n%s,un1;53.\'B&${she2ag{u?\'0g}#740b#1qn)sRn1{/k&*\'o><y', 'Zl~hl?\' pR=0u-c( $<:?p%L\x1f)"Bcpgvc?\'nd5+858/e;{-tB?bv$,udoxvkl+vet")pl1hab)w\x12!rwvne2ee\x7f$ivgew!>cabrcsi)$Qi1tyjt+%ickx', '[:&mmb%\x7f#Q=1${o(s$na>\'uH\x1c,\'@2&g&6i#>0ey9?<,18-# \x10eavs\x7f%c2/tnhs+4wsxr:3:b5u#Epsq&=k>f0xr:"f0u\';4>6repmz\'We3#|>\'%\'>;mu', 'Zntkgjt{x\x0603#|a&#%;a:$ I\x16/\'Fb 2$?h\'he1{oi;)a=-"&D44&${%:i~!=?++2"q(p:1o31}rD&  !=?:c7|&k*4cv-h33a 2\'i\x7f$Yiep|8#\'t89g&', '\x08hwnl;%}xW=0)\x7fa#p.ha?\'&\x1fJx/\x155$e|1o"90f(2of{ba\x7f\'}Bfnq")p7=)|?8~!f uz%i`oc`|pFv!qujnng0!s?#1ev >g?ar4 :*&Wl5r(;vq"k<:u', "Qjrk7hs|sU7`%~2&&t;hlp'J\x18)%Edp2padt=52y:8f,fjzs!\x16?d'w*%ak+r?lzp2p&z'>485`zsHq/r#o835b|%m#72rw<`7f$6q:/vTm2s\x7f1w!q8kl#", ']e"<1jq-x\x0203"xa(s%>h9\'%M\x1f{#Ee$4r>ow=6`\x7f;8h.g8\x7fp|A63#s.q;k~\'m<+p5%|,r?1454/!Bpwus:9>b0,"ovb7t$;gbf 6u:\x7f+Pkewr?uw"<mju', '^kr>`ku+xR`0"-as%s<hk%%LL\x7f\'\x13a#e\'>8+:2e{=il}`?+w|E3au#z$03x f<|+1\'&zqm585c}!\x15p&%|=9<d0(w?s;ft-?f3a#e\'k~!\x0494$+mw p>;n&', '\n9wncbt)\'Ub6#{au)$;<:-q\x1c\x1c{sBcw2ved!=0f,3;;.hh|s!Bbo\'v{%`9/%jo,#o&&,woch5e/vC" r!oe<db(r=qba\'"?`ae\'c"9t#Uj<t)? *~l8i!', 'P?wme? }q\x014m\',1((r?j6w!H\x1e~/Ba%?q78&l56\x7fio?*dj~tu\x142c/w,\'g;)"f={!4v% $o7mc>}wGp"t ?8jc4-p=pfbw!:1bd"fp:xpT86vrkr v<nfy', 'Zjwob?w\x7fx\x01<lrxb)uth:9vpL\x1a)/\x171p7|>iq=7f{:on,ikps#Cd5"%.wcn} =?.\'b q{#908g>(!@%\'&t<?32a\x7f"l$5e %jd1j#fu<\x7f+\x04d< /mvs~?8m"', '_>rg2?}.%Sa0)}`q t4l?w%M\x1d)sG8pc|fhtnbg/?mo.2l~s}\x17baqu+q:3u&g:|\'1uw)%?2<52-{Aws%$8ehncx!9+`e"!?ef`weugz*Plbpzkrs\x7fooiv', '\\itkbmu)\'Q4f"*5 w%9<8uv\x18Jy"D4\'`&e;poco. ...
# La función descifra() se ha ejecutado correctamente.
# El mensaje descifrado es: ^hs>bl!{x<mu1(#s<:7!$* H7vcs6m%n`a+hnh-1hzt}42'wrck&jj"`pt|~>253g({' %$?hofb#9#a4% <g0f'1wf('Yo4{(>t+":?kv
# Tiempo de ejecución: 757.35 segundos.
# 
