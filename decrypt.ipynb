# %%
#functions
import os
import time
import hashlib
import itertools
from langdetect import detect_langs

path = "C:\\Users\\peorr\\OneDrive\\Documentos\\GitHub\\ComputerSecurity\\decrypt"

########### GENERATE KEYS ###############################
def generate_key(k0):
    # Cálculo de k1 como un desplazamiento cíclico de 1 bit a la derecha de k0
    k1 = bytearray([(k0[0] >> 1) | ((k0[1] & 0x01) << 7), (k0[1] >> 1)])

    # Cálculo de los hashes SHA-512 de k0 y k1
    h0 = hashlib.sha512(k0).digest()
    h1 = hashlib.sha512(k1).digest()

    # Concatenar h0 y h1 para formar la clave de 1024 bits (128 bytes)
    key = h0 + h1
    return key.hex()

### One time pad ENCRYPTION 

def decrypt(ciphertext, key):
    # Convert ciphertext and key to binary using hex decoding
    ciphertext_bin = bytes.fromhex(ciphertext)
    key_bin = key.encode('ascii')

    # Compute the plaintext by XORing the ciphertext and key
    plaintext = ''.join(chr(ct_byte ^ key_byte)
                        for ct_byte, key_byte in zip(ciphertext_bin, key_bin))

    return plaintext

def convert_int_tuple_to_string(int_tuple):
    str_list = [str(num) for num in int_tuple]
    string = ''.join(str_list)
    return string

#convert to bytes
def convert_binary_string_to_bytes_and_bytearray(binary_string):
    # Convert binary string to bytes
    byte_data = bytes(int(binary_string[i:i+8], 2) for i in range(0, len(binary_string), 8))
    
    # Convert bytes to bytearray
    byte_data = bytearray(byte_data)
    
    return byte_data

#function that only returns the sentences with prob >=0.5 to be english language
def is_english(sentence, threshold=0.5):
    try:
        languages = detect_langs(sentence)
        for lang in languages:
            if lang.lang == 'en' and lang.prob >= threshold:
                return sentence
        return ""
    except:
        return ""

#function that returns the key used to encrypt the message
def descifra(texto):

    start_time = time.time()

    print("La función descifra() se está ejecutando...")
    
    

        
    
    # get the path of the file
    archivo_cifrado = os.path.join(path, texto)

    # generate all the possible keys
    combinations = list(map(convert_int_tuple_to_string, itertools.product([0, 1], repeat=16)))
    combinations = list(map(convert_binary_string_to_bytes_and_bytearray, combinations))

    # generate the keys from the combinations
    keys = list(map(generate_key, combinations))

    # open the file with the encrypted message
    with open(archivo_cifrado, 'r') as f:
        secret = f.readlines()
        print("El mensaje cifrado es: {}".format(secret[0]))
        f.close()

    # get the decrypted message
    dec = list(map(lambda x: decrypt(secret[0], x), keys))
    print("El mensaje descifrado es: {}".format(dec[560]))

    # verify the probability of the language
    check = list(map(is_english, dec))

    # delete the phrases that are not in english
    check[:] = (value for value in check if value != "")
    print("El mensaje descifrado es: {}".format(check))

    # verify the probability of the language again
    check2 = list(map(lambda x: is_english(sentence=x, threshold=0.9999), check))
    check2[:] = (value for value in check2 if value != "")

    # obtain the key
    clave = keys[560]
    elapsed_time = time.time() - start_time

    print("La función descifra() se ha ejecutado correctamente.")
    print("El mensaje descifrado es: {}".format(check2[:]))
    print("Tiempo de ejecución: {:.2f} segundos.".format(elapsed_time))

    return clave

# %%
print(descifra("Ciphertext-1.txt"))
# Out:
# La función descifra() se está ejecutando...
# El mensaje cifrado es: 695c475f545a4419416404551048571011170d580f1414792f1d167100120645075d125854574d0a0c5e18505949154527075717411941020a4d445e5e4a1357444419465b050c51064c4271151643455e5c0b575619405c12035644150e5707531407445f4c12615d04424a094212460a5a5f40
# El mensaje descifrado es: Y>w:miu/v67 {d&(ti:8v%I(pE6%3}>o+924)k9<z2ozv$?n q+y4?}!nl~'ct".vh1=iczq#wv|:?h`0,wi!;2"%63ebufpgx$Pdb{{jswqh?kw
# El mensaje descifrado es: ["^>%ocls)v\x062`%yb #%nn6r#\x1d\x1e|p\x13esev6jpk16.;<jya8,- \x1622.s*'a=~|n<\x7fraw!(whc;e5uvDw/z&g8?2o}&>&e3&tm`>d%f}h)*Y8`q+=p'p=jov", 'X8\x7fkgcs(vU=dt|`q  o>6u M\x19~/@3$5re>*`0a.88ozbl("#\x1135.wz%fhz}hir+2&t.pl5:36| D%%{\'l>?ed #kpbgwwke>k&4si}pV<7{smvtto8>w', '[iuh`8&-"\x010lq~asp/8l: -H\x16\x7f"@3%6\'7hsm74z><g/1;/s&\x105`#\'} a;/rh=.&o |,sn=?e6y\'Iw"%|hembc)pj$7fswha40v7 l}t\x00m5p(l{t%<om%', '\\lqfdct-"\x0254v)bssq?;8",\x1f\x1a~sGeqe|ddsn`6~o48+b;x  B0cuq,%foxskk| `rv-w9co03/!\x13!t{p:?n1b!$>!17",k`d2%0rjt$W;6s/0$*\x7fkmiv', '\x0bh#:lhw)tQ`e *4!#tio7rqHN|pF4wcs7k imb/8:l!6mptw\x12>f" *xa<y&;os#gu|+#l6n47-{Fvrqrkhn1b\x7fr9p14%!<6?6%b}j~w\x00k1p.={p#lo;x', '\x088sifhq+q\x06ae\'*ct q8om#%@K/$Hcpgwcj$=1c)=>;(hi, |Ef`$s v7=ywfhx"os\'|\x7f>0o7dzz\x10,\'\'v:k=an{yktf3pv9oaf\'7w>twYm5t\x7f=$&%9?oq', '\x0b:&g09!.%\\6l({a#$so9n-%\x1d\x1bx&\x107p?&4n$9m1}24j|d`\x7fvp\x1471   "13)vf:\x7fpepv-t>=md0{ F&\'vvn:mfe+tht:fpt;b3cubp9}tQ94r.9rww>o9s', 'Yov>6c"\x7ft]2gupf!".ln6$$K\x1e+/E5tep?is:eo{ki<)2?z!|\x1fda!p{x5<,smgyr1}p{p9foh1tv\x17"s{&<k>5f.q8w5f",h3fc"cpk(v\x05h2s/<qwu9nlx', '^hs>bl!{x\x00<mu\x7f1(#s<:7!$\x1c\x1a* H7vcs6m%n`a+hnh-1hzt}\x1542\'w\x7frck\x7f&jj\x7f"`pt|~>253g({\x17\' %$?hofb\x7f#9#a4% <g0f\'1wf(\'Yo4{(>t+":?kv', "\\is<g<v)qVb4r)ev&/=j=#q\x18N(u\x12cp6s1o+kmf|<h;y5m{%wE14!y!$c>/%<<|rfrs.vhf573)$\x12# wvj:?5n/sevebqw;d15raq9|'Tia&,<!t\x7f999$", '^i~<5l! #Vgms-3rtr=j:,$\x18\x1f/wHf!d#18!<5`{?ih-h`\x7f&sB6o!${s2k(&hjr*4ww.q9`i`3-zI \'\'pml2ag.so!3`"#;ad` btl{!Vofus1s*~??o!', 'Zl~hl?\' pR=0u-c( $<:?p%L\x1f)"Bcpgvc?\'nd5+858/e;{-tB?bv$,udoxvkl+vet")pl1hab)w\x12!rwvne2ee\x7f$ivgew!>cabrcsi)$Qi1tyjt+%ickx', '[:&mmb%\x7f#Q=1${o(s$na>\'uH\x1c,\'@2&g&6i#>0ey9?<,18-# \x10eavs\x7f%c2/tnhs+4wsxr:3:b5u#Epsq&=k>f0xr:"f0u\';4>6repmz\'We3#|>\'%\'>;mu', '_mt>flv+p]0dq|3t u?l<,$JK,sH1w4wensm61(=nl|ia}-\'\x1035vt*pf=yr?;x+6t}|#o3n4c/u\x14p.pui?;47(qh"70stk6?k 0w=| Rm0!{l##tiogs', 'Zntkgjt{x\x0603#|a&#%;a:$ I\x16/\'Fb 2$?h\'he1{oi;)a=-"&D44&${%:i~!=?++2"q(p:1o31}rD&  !=?:c7|&k*4cv-h33a 2\'i\x7f$Yiep|8#\'t89g&', '\x08hwnl;%}xW=0)\x7fa#p.ha?\'&\x1fJx/\x155$e|1o"90f(2of{ba\x7f\'}Bfnq")p7=)|?8~!f uz%i`oc`|pFv!qujnng0!s?#1ev >g?ar4 :*&Wl5r(;vq"k<:u', ']e"<1jq-x\x0203"xa(s%>h9\'%M\x1f{#Ee$4r>ow=6`\x7f;8h.g8\x7fp|A63#s.q;k~\'m<+p5%|,r?1454/!Bpwus:9>b0,"ovb7t$;gbf 6u:\x7f+Pkewr?uw"<mju', 'Zj#=`>")\'\x016lr+f)%\'oh=!&A\x16~p\x123!`valpj6oxo:m h?+vq\x1fcdst(wf;\x7fwo<{!bvs\x7f\x7fnf87d/rCpr"wlkm6a.qm%22|-<ead,f!n|\'X9eu\x7fhs"%ko;#', '\x0cerlf;|\x7f$Ugd&zf rq4n9\',@\x1b\x7f%D8*1$ah\'97auh;?!3h*t&\x1315%v-y6o/"?f(%as!zp=7ife\x7f!\x15-ws|fknbn,snsf3|"h37kr>&;\x7f \x05if \x7f9r%%3>jr', "[9p90ku+$\\1b$-2!w%lj:%,\x1fN*.Adsbqf?*l22~inh}`ay!p\x12bg.p/ 0k)%om(ueq!+ >0841uvB'.vs8o:`4!s=&:0w$93cf%6!o}'\x07<1 .h&+ 8lou", '_ishf?p,s\x0637s{o$#%noj\'"N\x1d)%Fct7\'7m*l65.k4mz2m~-$A3d!$*%4k|smn~pgwtxpnd9fd(r\x10$%ppg:3b0/#m+5`r-7ab1#3 fz+\x05d0zzls $>o;p', 'Zjwob?w\x7fx\x01<lrxb)uth:9vpL\x1a)/\x171p7|>iq=7f{:on,ikps#Cd5"%.wcn} =?.\'b q{#908g>(!@%\'&t<?32a\x7f"l$5e %jd1j#fu<\x7f+\x04d< /mvs~?8m"', '\x0c:p=ec|)\'W06\'{`%&&:98$qI\x1b(pAe$3w2?%91f{n<:/2o/w!\x167o/%| `:{wof)u3r \x7f"c`jf7-t\x14 wpw?j81`+!dp25 v?b6a$esf\x7f%Yibz\x7fl&ss2<:&', '\x0c>rfbjr!%\x05=m!,`v&&==:\'\'\x1b\x16+&G4s5q3k+>d`.k:f|hi}w!\x14d3 w+y:i(sfo)#4&s!">f=5?(r@q%v}nj8a5 y9&ee!\':13d\'dvo\x7f\'\x00h1\'sh *u=l:"', '\x08l$n0j\' y\\0er-n"#$ij>pqJ\x17.pB9pd$3ms`a4{34i{5:xw#\x1775 w(tfi~tmg\x7f%4pr+s86j42- B#\'%!:9ne2!x?s0cvt6`>f$arit$Rng!)h w ;;f&', '\x0bmvj19w|u\x01g0u,c)$$hamp$O\x18%s\x10a"4w?e&;lat;:f `h-,qB36/w(s`>(t;=xr3r%{#bc;d7xzA##vt=h2d2.uks65rq7b31%6w=/q\x058=z(8&t~9kn%', '\\itkbmu)\'Q4f"*5 w%9<8uv\x18Jy"D4\'`&e;poco.:jm{bmq !Cf1up/vc9+tiny!1!\'*%==824* I%srqo:of5-%d%42|%mcbcw1um}tYl4z/ouw"=o=p', 'Plrlcls)"\x06fa&\x7fb#\' n9l,qIJ\x7fw\x139s`ra9"`6c,?hk~1nzstA2fqs/#`8x}in| 5r}.\x7fbf5h7}#\x17,%zvhjo30,ye+g0%v9`e`ufsn-$W<3t|l$" 8;jy', '\\>q<gi|!q]gc"-erp/:n;",H\x1a.#Ccp`sel+>g`+h?f.1<+wvF?fts)t3iyvhm\x7f\'5rw. j08h6- \x10\'/utmono4.$hqb3v\'9445wfr<}w\x00h`\'\x7 ...
# La función descifra() se ha ejecutado correctamente.
# El mensaje descifrado es: ['^hs>bl!{x\x00<mu\x7f1(#s<:7!$\x1c\x1a* H7vcs6m%n`a+hnh-1hzt}\x1542\'w\x7frck\x7f&jj\x7f"`pt|~>253g({\x17\' %$?hofb\x7f#9#a4% <g0f\'1wf(\'Yo4{(>t+":?kv', '_mt>flv+p]0dq|3t u?l<,$JK,sH1w4wensm61(=nl|ia}-\'\x1035vt*pf=yr?;x+6t}|#o3n4c/u\x14p.pui?;47(qh"70stk6?k 0w=| Rm0!{l##tiogs', 'Qh$lml}( Qb7$.5 ).oi>wp@\x1f,rB4$0}?8sim5|;8f 3kp\'!C0f"" ";o\x7fv;m.wo%q.~ld=aeyu\x12!\'ur?e=a0}!lp;epw85>e$4tox+Qjevr<&*\x7f<<:y', 'Qe\x7fjf>r|$\x00glq{b %!8m9 pOJypG9*5s4< a6`x;<8|5n|ws\x17b4!%(q`9|p;?~uopwz"?f>a2uqI!   j822f\x7fy:+fg&-8`c6!?soysQ;fts0q%so;;r', "\x08lw=f8v*%\x011l(\x7fo)p n=9rpO\x1fx B6t1sek$k7b\x7f>8h*`8(t}A>nv$/%3iytkf/rewt-qm6=f>tv\x17wws|mh8ea)p='5f&'=330qbqk{&Xj7v\x7f8pqvkmmv", 'Pit;7bvz#\\3bt|osr$h<kupA\x1a*&\x152w6wb8t;b6,8m=,aa\x7fpp\x1e7f/%|rd?xpfl\x7f#epw/pn7m0btp\x15sszshemfg!$?!a0p$6ffc!4!jz#S91!}0p #3hor', '\x0firg1kvxuW0au-2\'%&;:;%\'\x1d\x1f|r\x138 c|fk\'=mc+99<,hj~ s\x162f\'s y;iys?ns c%".\x7fn1?2busE"sq =><ca rm$23&vh635%er>t+R?=p}:!"t=jht', '^:$=6br*w\x00aa).5!\'$;`;v%J\x1e+"Fa+4p08$a72y29i*alzwtBd3/%*wf=twjo(#3v\'\x7f\':<n0`\x7f!\x10s% vh?h1a}y=s5o}tm3b0 fsm{pPe2t.8qws8kkr', '_>!h7<t v\x004f%+f&(&;j<w$\x1a\x1b|$I3%5uan";c1(>h8*6:ps&\x17ab& {tf<, ml{"3"t!$:2:2gxs@p&!ukim4n}tow6n},:bbf$?|<.\'T>5!}:tt"h;gp', ']ksn6bw)pTbm#{c!s/ok7qwH\x17*"C5%?\'7;tllb.?9:.g`/&p\x1fb4/"{"c>t&of,wes!zp9f955~$\x13$\'sri>;n0/p?&;d ,oof1!6ph(*W;1!):u!\x7flif"', '^8vgdn|,tSb4rqe!"t=j8w\'\x1cJ%wD6 2 6esn62{?9f.eoz-!\x1504 u\x7fud<~":f)p6v%{#?6h35|uBpws&=:<a2{&ot2b\' k4fcu3!f~!\x03of#x;u$"hn:y', '\\oum2ip{pW7bqy1s /om9v"I\x19/\'\x134wd ed#ib1,kog!a`(#t\x14b`st!uchy\'jk+!3}\'x\x7f>5955{uC!ur!imif3\x7fv:%edw!o21frd&<t Qo4{/9p*s<n;$', 'Ph!o7;pxy\x020`t}f)!&5h>r%L\x1e+w\x14fq0s18+>e4}2=k-en|%|\x14e3#qxufi||hly$6"v($:0;g3)vA%sqs8d26`+&hsf2 &74fj\'4&g/t\x008a!}>rpp:mm$', "\\evo6bu-rP4`s\x7f`#t/=mn-%\x1fK,uD0%cw3; i`g\x7f3hj*e;}!tD>a!$ s1n\x7f|foz*2'q{rkf?c1.'\x12ww{w;>ib0!sn*43wq;1>2q7%f.+Phf$(:r'p<hmp", 'Pop<0ov{$T30 ynqpsh:?\'p\x1dJ%w\x137 dv4n\'mbgy;=<(38(vwD?guu p13+|hhs&c &,wj3oh3*pA-/"shn>b4}#9*b2w,73e5w2tg|&W>4txop"q:jku', '[dti2ow)p\x05ec\'z2$w#:m<%vO\x18\x7f/D6"`!69s`fo.2of|ci|,v\x17a2s\'{#7ly"ii,*`}w*~k0:76(q\x13t\'vwjj850*sev;2 q?f>` ewg}sP9aq)m\' r<li$', 'Q=vhdct|w]ebq}1$#"=h:$$A\x1fxp\x10a*2\'aisk7f~2h;!d<(-p\x147g$s.u6;\x7f\':mz 3ww(#ngm31(pH%%z!:nmbo-so+forwh25` 3v>x \x02ee&x=tqs<mh$', '\x0f=v<gh .vVf`q}6%&#89<w,IJ~r\x155p3#f8tklbulh8/6a-\'\'\x11c5%"/":;\x7fwl;zpn\'r)vh5=cg*uDs!%#nkjad-!ep4o%$mg2fu3so~vU<0 /k! \'noo&', '\nnrmeow{u\x015`vyg(%.h;;#"LK{$Fa&>vd?!;c`|>?j*`mz%w\x15f6rq.pfo+|kg{rg v+wh4of1~wF,!tvnj8ao.%h*fg%p=o1bqavlt+V>4#+9#&w;;fv', '\x0fhug1ns{\'Teds|a)rt<h= \'NM+.Fcp>wems<an};=<-c?q,rF7dvx(tai}"im,po|"/~?09bdz Fqw }i8;1`!&:*:`qpln1d btn-p\x0594#+m&"ph9gx', "\x08?wgb9p #P5m(y`t)t5m9v%LM-tI6s7t6e&`a3\x7fh?j+ho(  \x13cc$#/ud3/%<mx&f%t+w=6ne2('\x14#/{!?l9d0,%m+fbv'6c4fvftf-!\x03kbvxo##piiop", 'Yh~;1;wx"Q4bs+`u!#5;9$ \x1c\x1b)t\x131#6s0<snee.><f-hm,qr\x1eeb#p/\'0?z%?f,%ntt "9f:25-!E$%pq=:9bn,#d$6osv8gck#b\'g|*Um=pyht$\x7fljh%', ']9"glhr,u\x07a0t\x7feup%8k:q,\x1c\x1cy"H1%b$0htkc`u=jhz6h/ts\x16>e% |q5;t fj(w4"v.wh0>03uwA stsf83d3}#o#fet\'ofeer3|otp\x02>2v/m!t okjw', 'Pesmf9 ) \x06f`v\x7ff((qio:!"@\x1b$w\x12bvev6lwhb4u>hiy5n|-qE21%$,t5:x :?)!6uu{vk19d3tw\x14s#" flooc-$e!4ou,8eec,7}lyv\x00n0us;!+vkc9u', 'Qn$9an|(xTe7t~4"& o9kp-\x1d\x18.wD9&5te?p=f3(nnn~f<(svE25&p #al(}:j,p5}p/v>3<35- Aq$q&fmnbf{q?*bb& ?212p>};*wVk2\',;#w~o8iq', '\nhrn`ms/q\x007cq-a)s"hl>!$OL\x7f.B0w7s7jvked/;?m+cm/%r\x14f3!t yc<\x7f}j=s#f&\'\x7fu97>5d/$\x13tt!&ih2b0+uk&`c"$=f6k\'asm{$Ue0r|;#*"kkfw', 'Yos9fnp)r\x0216qycqss8=; qJ\x16/!\x176+>#b;pnf1ti=jz``/"\'C0f.\'*#6kt%8:,vc%%}#j282`}uHq"uvgnn24xv>&ear,;64b&1|f\x7ftU>2#\x7f:&w$<clw', "Z>ph7ks}wQ0bqx3r% 8j:'!KM+$\x103&cs>?q`c1x84f~bo+wwB7f!$}#43x'ml~v5tvzqmc:`?\x7f$G$wqwokoff}x8sag%$hcfbq>r:~t\x04n6w~j$$'2bot", '_o!h0hu-tWa`s~e(#sh>k&wI\x19-/Aet7|?9w=`2z>?f+a`*t!\x14b6/"/x2?|wll.$c!w+r:`i3c-#\x15s/pq?nneexwhv1a%wh6f0!f"=/#\x03e6#~k!%$ijk!', 'Xh$=f<q, \x07f3v{f\')/=9l!"\x1a\x19(!Ea!ep5 ...
# Tiempo de ejecución: 817.97 segundos.
# 
